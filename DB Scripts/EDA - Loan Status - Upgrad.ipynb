# %%
import os
os.getcwd()
# Out:
# 'E:\\SmartCube\\End to End Code'

# %%
os.chdir(r'E:\SmartCube\End to End Code')

# %%
import pandas as pd

# %%
df = pd.read_csv('Python_Credit_Risk_XTrain.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
len(df)
# Out:
# 614

# %%
len(df.columns)
# Out:
# 13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 62.5+ KB

# %%
df.head(2)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
#
#    Credit_History Property_Area  Loan_Status
# 0             1.0         Urban            1
# 1             1.0         Rural            0

# %%
df.tail(6)
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 608  LP002974    Male     Yes          0  Graduate            No
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 608             3232             1950.0       108.0             360.0
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
# ...

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History  Loan_Status
# count      564.000000   614.000000
# mean         0.842199     0.687296
# std          0.364878     0.463973
# min          0.000000     0.000000
# 25%          1.000000     0.000000
# 50%          1.000000     1.000000
# 75%          1.000000     1.000000
# ...

# %%
#Measure of central tendency 
    #Mean
    #Median 
    #Mode 
    
#Measure of spread 
    #Range 
    #Variance 
    #Standard deviation 
    #IQR - Inter quartile range

# %%
import seaborn as sns

# %%
sns.distplot(df['LoanAmount'])
# Out:
# C:\Users\rahul\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='LoanAmount', ylabel='Density'>

# %%
sns.boxplot(data=df, y='Property_Area', x='LoanAmount')
# Out:
# <AxesSubplot:xlabel='LoanAmount', ylabel='Property_Area'>

# %%
sns.countplot(data=df, x='Gender',hue='Loan_Status')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# **From the above chart we can say that gender is not really an important variable to decide the loan status**

# %%
sns.countplot(data=df, x='Married',hue='Loan_Status')
# Out:
# <AxesSubplot:xlabel='Married', ylabel='count'>

# %% [markdown]
# **If you are married there are a bit of a positive chance to get a loan**

# %%
sns.countplot(data=df, x='Dependents',hue='Loan_Status')
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='count'>

# %% [markdown]
# **No of dependents is not important feature**

# %%
sns.countplot(data=df, x='Education',hue='Loan_Status')
# Out:
# <AxesSubplot:xlabel='Education', ylabel='count'>

# %% [markdown]
# **If you are graduate then you may get loan**

# %%
sns.countplot(data=df, x='Self_Employed',hue='Loan_Status')
# Out:
# <AxesSubplot:xlabel='Self_Employed', ylabel='count'>

# %% [markdown]
# **Self employed does not matter**

# %%
sns.countplot(data=df, x='Property_Area',hue='Loan_Status')
# Out:
# <AxesSubplot:xlabel='Property_Area', ylabel='count'>

# %% [markdown]
# **If you are coming from semi urban the chances are high that you will get a loan**

# %%
sns.countplot(data=df, x='Credit_History',hue='Loan_Status')
# Out:
# <AxesSubplot:xlabel='Credit_History', ylabel='count'>

# %% [markdown]
# **Credit history makes lot of sense to get a loan**

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.Loan_Amount_Term.unique()
# Out:
# array([360., 120., 240.,  nan, 180.,  60., 300., 480.,  36.,  84.,  12.])

# %%
sns.countplot(data=df, x='Loan_Amount_Term',hue='Loan_Status')
# Out:
# <AxesSubplot:xlabel='Loan_Amount_Term', ylabel='count'>

# %% [markdown]
# **If your tenure is 480, the chances of rejection is high, and there are more number of loans with 360 months**

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
sns.lmplot(data=df, x='ApplicantIncome',y='CoapplicantIncome', hue='Loan_Status',fit_reg=False)

# %%
sns.lmplot(data=df, x='ApplicantIncome',y='LoanAmount', hue='Loan_Status',fit_reg=False)

# %%
sns.lmplot(data=df, x='CoapplicantIncome',y='LoanAmount', hue='Loan_Status',fit_reg=False)
